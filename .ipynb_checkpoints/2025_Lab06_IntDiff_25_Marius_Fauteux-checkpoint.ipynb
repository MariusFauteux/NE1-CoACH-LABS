# %% [markdown]
# Neuromorphic Engineering I

# %% [markdown]
# ## Lab 6: Integrator Circuits

# %% [markdown]
# Group number:
#
# Team member 1:
#
# Team member 2:
#
# Date:

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Objectives of this lab:**
# In this lab we will begin to explore the time domain using the follower-integrator and the follower-differentiator circuit.
#
# Both circuits simply contain a transconductance amplifier and a capacitor to implement a low-pass or high-pass filter. We will use the follower-integrator (FOI) and follower-differentiator circuit on the CoACH chip. **The capacitance for both capacitors is $1pF$.**
#
# In particular, we will:
# 1. Understand the behavior of the first-order low-pass follower-integrator and high-pass follower-differentiator circuit in the time and frequency domain in small signal operation.
#
# <div style="border: 2px dotted blue; margin: 1em 0 1em 2em; padding: 1em 1em 0.5em 1em">
# <em><b>First-order</em></b> means that the transfer function amplitude decreases as 1/frequency.
#
# <em><b>Low-pass</em></b> ( <em><b>High-pass</em></b> ) means that the circuit passes low (high) frequencies and blocks high (low) frequencies.
#
# <em><b>Follower-integrator</em></b> ( <em><b>Follower-differentiator</em></b> ) means that the output follows the input at low (high) frequencies, and integrates (differentiates) at higher (lower) frequencies.
# </div>
#
# 2. Understand the large signal behavior and other limitations of using a transconductance amplifier to model a linear resistor.

# %% [markdown]
# # 1 Reading

# %% [markdown]
# See **Chapters 8** and **9** of the _Carver Mead_ book (_"Analog VLSI and Neural
# Systems"_), paying particular attention to the time and frequency domain
# treatments of the RC circuit \[pg. 240-241 and 246-249 in Chapter 8]
# and the follower-integrator circuit \[pg. 252-256 in
# Chapter 9]. Slides are also available introducing linear systems analysis.

# %% [markdown]
# # 2 Prelab

# %% [markdown]
# 1. <font color=#108ee9>How are capacitors constructed in CMOS chip technology?</font>  _There are  several different possible implementations._

# %% [markdown]
# 2. <font color=#108ee9>How are capacitors constructed in neurons?</font>

# %% [markdown]
# 3. - <font color=#108ee9>What is the capacitance per square micron of a SiO$_2$ capacitor with oxide thickness of 10nm?</font>
#    - <font color=#108ee9>What is the capacitance per square micron area of a lipid-bilayer capacitance with thickness of 5nm?</font>
#
# <div markdown="1" style="border: 2px dotted blue; margin: 1em 0 1em 4em; padding: 1em 1em 0.5em 1em">
#
# You will need to look up the dielectric constants for SiO$_2$ and lipid bilayers. Remember to provide your sources in your writeup.
#
# One standard source for lipid bilayers is _Ohki, Shinpei_: [_"Dielectric constant and refractive index of lipid bilayers"_](https://www.sciencedirect.com/science/article/pii/0022519368900088) \[Journal of Theoretical Biology 19.1 (1968): pg. 97-115]
# </div>

# %% [markdown]
# | Dielectric constant | Value $\left[F/m\right]$ |
# | :------------------ | :-: |
# | $\varepsilon_0$     | ? |
# | $\varepsilon_{ox}$  | ? |
# | $\varepsilon_{mem}$ | ? |

# %% [markdown]
# 4. <font color=#108ee9>Derive the transfer function $H\left(s\right)=\frac{V_{out}}{V_{in}}$ for the **follower-integrator**.</font> Use the $s$-plane notation, expressed in terms of complex frequency $s$ and the time constant $\tau$.

# %% [markdown]
# <!-- ![coach@CoACH180,follower_integrator,schematic.png](attachment:coach@CoACH180,follower_integrator,schematic.png) -->
# ![foi.png](attachment:f4b3ddad-8526-40c6-ae5e-4df58c50b8df.png)

# %% [markdown]
# 5. <font color=#108ee9>Compute the transfer function $H(s)=\frac{V_{out}}{V_{in}}$ for the **follower-differentiator**.</font> Use the $s$-plane notation, expressed in terms of complex frequency $s$ and the time constant $\tau$.

# %% [markdown]
# <!-- ![coach@CoACH180,follower_differentiator,schematic.png](attachment:coach@CoACH180,follower_differentiator,schematic.png) -->
#
# ![fod.png.png](attachment:69681ab4-542d-4941-a1d1-8623dcf216ec.png)

# %% [markdown]
# 6. <font color=#108ee9>Compute the magnitude $\left|H\left(s\right)\right|$ for the **follower-integrator** for input angular frequency $\omega$.</font> At what frequency $f$ in Hz does the power drop to half its low frequency value (amplitude drops to $1{\large/}\sqrt{2}$)?

# %% [markdown]
# 7. <font color=#108ee9>Compare the simple _RC_ integrator, constructed from a resistor and a capacitor, with the follower-integrator to show how the transfer function falls short in describing the follower integrator.</font> In particular, how does the follower integrator respond to large signal inputs?

# %% [markdown]
# 8. <font color=#108ee9>What does _"small-signal"_ mean?</font>  In other words, what voltage range will this regime correspond to?  For the follower-integrator circuit is it the _amplitude_ of the input, of the output or the _difference_ between the two that matters? Why?

# %% [markdown]
# # 3 Setup

# %% [markdown]
# You may want to install all the necessary requirements (python libraries)

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt --upgrade # note upgrade to update jupyter-save-load-vars
# you may need to restart kernel if new libraries got installed.
# Out:
# Requirement already satisfied: numpy in /Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: matplotlib in /Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (3.9.4)
# Requirement already satisfied: scipy in /Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: engineering_notation in /Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: schemdraw==0.10.0 in /Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.10)
# ERROR: Ignored the following versions that require a different python version: 1.14.0 Requires-Python >=3.10; 1.14.0rc1 Requires-Python >=3.10; 1.14.0rc2 Requires-Python >=3.10; 1.14.1 Requires-Python >=3.10; 1.15.0 Requires-Python >=3.10; 1.15.0rc1 Requires-Python >=3.10; 1.15.0rc2 Requires-Python >=3.10; 1.15.1 Requires-Python >=3.10; 1.15.2 Requires-Python >=3.10; 1.15.3 Requires-Python >=3.10; 1.16.0 Requires-Python >=3.11; 1.16.0rc1 Requires-Python >=3.11; 1.16.0rc2 Requires-Python >=3.11; 1.16.1 Requires-Python >=3.11; 1.16.2 Requires-Python >=3.11; 1.16.3 Requires-Python >=3.11; 2.1.0 Requires-Python >=3.10; 2.1.1 Requires-Python >=3.10; 2.1.2 Requires-Python >=3.10; 2.1.3 Requires-Python >=3.10; 2.2.0 Requires-Python >=3.10; 2.2.1 Requires-Python >=3.10; 2.2.2 Requires-Python >=3.10; 2.2.3 Requires-Python >=3.10; 2.2.4 Requires-Python >=3.10; 2.2.5 Requires-Python >=3.10; 2.2.6 Requires-Python >=3.10; 2.3.0 Requires-Python >=3.11; 2.3.1 Requires-Python >=3.11; 2.3.2 Requires-Python >=3.11; 2.3.3 Requires-Python >=3.11; 2.3.4 Requires-Python >=3.11; 3.10.0 Requires-Python >=3.10; 3.10.0rc1 Requires-Python >=3.10; 3.10.1 Requires-Python >=3.10; 3.10.3 Requires-Python >=3.10; 3.10.5 Requires-Python >=3.10; 3.10.6 Requires-Python >=3.10; 3.10.7 Requires-Python >=3.10
# ERROR: Could not find a version that satisfies the requirement pyplane (from versions: none)
# ERROR: No matching distribution found for pyplane

# %% [markdown]
# ## 3.1 Connect the device

# %% [markdown]
# Import necessary python libraries. The cell below may be collapsed.

# %%
import time # for time.sleep(seconds)
import numpy as np # numpy for arrays etc
from scipy import stats # for stats.linregress
from scipy import interpolate
import matplotlib
import matplotlib.pyplot as plt # for plotting
import matplotlib
plt.rcParams.update({'font.size': 12}) # make the detault font size larger for your readers
matplotlib.rcParams['pdf.fonttype'] = 42 # save fonts as type that are not outlined in illustrator or other drawing programs
from engineering_notation import EngNumber as ef # format numbers in engineering format quickly, e.g. ef(2e-9)='2n' https://pypi.org/project/engineering-notation/
from pathlib import Path # used for saving data

from IPython.display import display, Markdown, Latex

datapath = Path('data/lab6') # make a data folder to save your data called data/lab5
datapath.mkdir(parents=True, exist_ok=True)
from jupyter_save_load_vars import savevars, loadvars
from tqdm import tqdm

import pyplane # for type hinting of biasgen constants
from ne1 import Coach # import Coach() class
import logging
p=Coach(logging_level=logging.INFO) # NOTE change to INFO to reduce clutter - create a Coach object called p; you will use it to talk to class chip, change to logging.DEBUG for troubleshooting
# p.open()

# below lines are notebook magic for debugging, you can uncomment them when debugging the Coach() class
# %load_ext autoreload
# %autoreload explicit
# %aimport ne1

# %%
p.open() # test it
p.close()
# Out:
# [INFO]: 2025-11-03 12:34:08,722 - NE1 - Opened CoACH at /dev/cu.usbmodem76219301 with firmware version (1, 12, 5) (File "/Users/mariusfauteux/Documents/NE1-CoACH-LABS/ne1.py", line 175, in open)
# [INFO]: 2025-11-03 12:34:08,723 - NE1 - closing device (deleting pyplane.Plane() object (File "/Users/mariusfauteux/Documents/NE1-CoACH-LABS/ne1.py", line 250, in close)

# %% [markdown]
# # 4 Follower-integrator (FOI)

# %% [markdown]
# ## 4.1 Schematic and pin map

# %% [markdown]
# <!-- ![coach@CoACH180,follower_integrator,schematic.png](attachment:coach@CoACH180,follower_integrator,schematic.png) -->
# ![foi.png](attachment:41b74b9d-9b2f-470d-bdb6-f30f299903a8.png)

# %% [markdown]
# **$$
# \begin{alignedat}{4}
# & V_{in}  && = {FOI\_VIN\_VI} && = \quad && AIN9
# \\
# & V_{out} && = {FOI\_VOUT\_VO} && = &&  ADC[10]
# \\
# & C  && = {C_{\text{eff}}}  && =  && 1 \text{pF}
# \end{alignedat}
# $$**

# %% [markdown]
# * The $W/L$ of the output transistor of the BiasGen is $4\text{u}/12\text{u}$, and the bias transistor $M_b$ of wide-range-transamp is $1\text{u}/1\text{u}$, which give a ratio of <b>$w$ = 3</b>. This means if you set the bias current to (3.8 nA, 225), you will get $I_b = 3.8\times\frac{67}{256}\times3 = 3$ nA instead of 1 nA.

# %% [markdown]
# ## 4.2 Time-domain response of small signal

# %% [markdown]
# ### 4.2.1 Set parameters

# %% [markdown]
# - The maximum sampling frequency of the ADC is 100 kHz (10 $\mu$s).
# - The maximum number of samples is 250.
# - What should the value of $\tau$ be (assume $\kappa=1$) if we want to cover the time period of $10\tau$ with these 250 samples?

# %% [markdown]
# <div markdown="1" style=" border: 1px solid green; border-radius: 5px; /*background-color: #d1a2a2; */ margin: 1em 0 1em 4em; padding: 1em 1em 0.5em 1em">
#
# In order to cover a period of $10\tau$ with n samples, each sample should have the duration
# $$\Delta t = \dfrac{10\tau}{n}$$
# As
# $$f = \dfrac{1}{\Delta t}$$
# it can be inferred that
# $$\tau = \dfrac{n}{10f}$$
# Setting $f = 100 \cdot 10^3 \text{Hz}$ and $n=250$ yields
# $$\tau = 250 \cdot 10^{-6}\text{s} = 250 \mu\text{s} $$
# </div>

# %% [markdown]
# - For what value of $I_b$ do we achieve this $\tau$?

# %% [markdown]
# <div markdown="1" style=" border: 1px solid green; border-radius: 5px; /*background-color: #d1a2a2; */ margin: 1em 0 1em 4em; padding: 1em 1em 0.5em 1em">
#
# The transconductance of the OTA is
# $$\tau = \dfrac{2U_T}{I_b\kappa}C$$
# With $U_T \approx 25\text{mV}$, $\kappa = 1$, $\tau = 250\mu\text{s}$ and $C = 1\text{pF}$ it follows that
# $$I_b = \dfrac{2U_T}{\tau}C \approx 200\text{pA}$$
# </div>

# %% [markdown]
# * What `MasterCurrent` and `fine` value should we use for $I_b$? Please set below.

# %% [markdown]
# <div markdown="1" style=" border: 1px solid green; border-radius: 5px; /*background-color: #d1a2a2; */ margin: 1em 0 1em 4em; padding: 1em 1em 0.5em 1em">
#
# For a given value of $I_b$, it is sensible to choose the next largest value for $I_{BG_{master}}$. In the case of $I_b = 200\text{pA}$, this is
# $$I_{BG_{master}} = 460\text{pA}$$
# With $I_b = 200\text{pA}$ and $w=3$, it can be calculated that
# $$BG_{fine} = \dfrac{256I_b}{wI_{BG_{master}}} \approx 37.10 $$
# which has to be rounded down to
# $$BG_{fine} \approx 37$$
# as $BG_{fine}$ must be an integer. The resulting bias current would come down to
# $$I_b = w\dfrac{BG_{fine}}{256}I_{BG_{master}} \approx 199.5\text{pA}$$
# </div>

# %%
p.open()
p.setup_foi() # setup the follower-integrator device
# Out:
# [INFO]: 2025-11-03 12:34:15,796 - NE1 - Opened CoACH at /dev/cu.usbmodem76219301 with firmware version (1, 12, 5) (File "/Users/mariusfauteux/Documents/NE1-CoACH-LABS/ne1.py", line 175, in open)

# %%
Ib = p.set_foi_ib(pyplane.Coach.BiasGenMasterCurrent.I460pA, 37)
print(f'The Ib current is set to {ef(Ib)}A')
# Out:
# The Ib current is set to 200.24pA

# %% [markdown]
# ### 4.2.2 Data aquisition

# %% [markdown]
# * Imagine the input voltage has been $V_{in} = 0 \text{V}$ for a very long time, such that the system is in steady state, <font color=#108ee9>what would then be the value at the output $V_{out}$?</font>

# %% [markdown]
# Then $V_{out}=0$ or close to it, since the capacitors will have time to decharge completly

# %% [markdown]
# * Given the definiton you provided of _"small signal"_ in the prelab, if a sudden change $\Delta$ in $V_{in}$ appeared in the scenario of the previous question, <font color=#108ee9>what would be its maximum value that still counts as _"small signal"_?</font>

# %% [markdown]
# $$|\Delta V_{in}| < \frac{2U_T}{\kappa}$$
# With $U_T \approx 25\text{mV}$ and $\kappa \approx 1$ (as assumed initially):
# $$|\Delta V_{in}|{\text{max}} \approx 50\text{mV}$$

# %% [markdown]
# * <font color=#108ee9>Verify your answer.</font> Try setting the value of `Delta_Vin_foi` to 10mV less of the $\Delta$ you calculated in the previous question.

# %%
Delta_Vin_foi_small = 10e-3 # Insert your value
Delta_Vin_foi_small
# Out:
# 0.01

# %% [markdown]
# * As initial state of the FOI, one would think that choosing the common mode voltage, wihch with the power supply $V_{DD}=1.8V$, results in $V_{cm}=0.9V$, would be a good idea. In general this is true, however, in our case, the harvested data looks better for lower operating voltages. In this case, $V_{\text{in, baseline}} = 0.4V$.

# %%
# the DAC has an offset, we compensate for it
# see next info spec
Vin_start_foi = p.foi_compensate_vin(0.4)

# %%
trans_time_step = 20e-6
iter_num = 10

Vout_foi_small = np.zeros(511)

# we run experiment multiple times to average the result and remove noise
for _ in tqdm(range(iter_num)):
    _ = p.set_foi_vin(Vin_start_foi)
    time.sleep(0.5)        # wait for the cirucit to reach steady state
    # run a transient response analysis
    # we record for 20 us (511) samples and store the result
    Vout_foi_small += p.transient_response( \
        pyplane.DacChannel.AIN9,      \
        pyplane.AdcChannel.AOUT10,    \
        trans_time_step,              \
        Vin_start_foi + Delta_Vin_foi_small)
    time.sleep(0.5)         # wait to receive the measured data from the microcontroller

Vout_foi_small /= iter_num
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]

# %%
t = np.arange(-10, len(Vout_foi_small)) * trans_time_step

# how many samples to print
# 0 < cutoff < 511
# too small and we don't see the steady state
# too big and the transition is hidden in the scale
cutoff = 200

step = np.ones(len(t)) * Vin_start_foi
step[10:] += Delta_Vin_foi_small

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(t[10:10 + cutoff], Vout_foi_small[:cutoff])
plt.plot(t[:cutoff], step[:cutoff], 'r--', linewidth=0.7, alpha=0.7)
plt.plot(t[:cutoff], np.ones(len(t[:cutoff])) * Vin_start_foi, 'k', linewidth=0.4, alpha=0.7)
plt.xlabel('$t$ [s]')
plt.ylabel('$V_{out}$ [V]')
plt.legend(
    [
        f"$V_{{out}}$",
        f"$V_{{in}} = {ef(Delta_Vin_foi_small)}V \cdot u(t) + {ef(Vin_start_foi)}V$"
    ], prop={'size': 14})
plt.title('Fig. 1: Step response of the follower-integrator for small signals')
plt.show()

# %%
# if the data looks nice, save it!
savevars(datapath/'4.2.2_foi', overwrite=True)
# Out:
# [INFO]: 2025-11-03 11:34:21,250 - saveloadvars - Saved to data/lab6/4.2.2_foi variables [ datapath Ib Delta_Vin_foi_small Vin_start_foi trans_time_step iter_num Vout_foi_small t cutoff step fig ax ] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 219, in savevars)
# [WARNING]: 2025-11-03 11:34:21,251 - saveloadvars - could not pickle: ['p'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 221, in savevars)

# %%
# maybe you need to load your saved data?
# loadvars(datapath/'4.2.2_foi', overwrite=True)
# Out:
# [INFO]: 2025-11-03 11:26:50,453 - saveloadvars - from data/lab6/foi_large_4.3.2 loaded variables ['datapath', 'Ib', 'Delta_Vin_foi_small', 'Vin_start_foi', 'trans_time_step', 'iter_num', 'Vout_foi_small', 't', 'cutoff', 'step', 'fig', 'ax', 'v_tau', 'tau_foi', 'Ibe', 'Ibm', 'taue', 'taum', 'kappa_foi', 'Delta_Vin_foi_large', 'Vout_foi_large'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 287, in loadvars)
# [INFO]: 2025-11-03 11:26:50,454 - saveloadvars - overwrote existing variables ['datapath', 'Ib', 'Delta_Vin_foi_small', 'Vin_start_foi', 'trans_time_step', 'iter_num', 'Vout_foi_small', 't', 'cutoff', 'step', 'fig', 'ax', 'v_tau', 'tau_foi', 'Ibe', 'Ibm', 'taue', 'taum', 'kappa_foi'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 325, in loadvars)

# %% [markdown]
# * <font color=#108ee9>Does this data validate the _"small signal"_ assumption? Explain you reasoning.</font>

# %% [markdown]
# Yes, since we can see that the output voltage is following a smooth first-order like exponential curve. The voltage difference is also very small and there is no saturation effect. This means it is oparating in it's linear regime.

# %% [markdown]
# * <font color=#108ee9 markdown="1">Is the assumption _"input step happens at exactly $t = 0$"_ validated by the measurement? If not, how can you get the actual time it takes place?</font>

# %% [markdown]
# No, it is close to be at $t=0$ but not perfeclly. To find the actual time we could inspect the response of $V_{out}$ visually to see when it change from it's steady state. But a more precise way would be to fit the measured data to the theorical exponential response: $$V_{out}(t) = \Delta V_{in}(1 - e^{-(t-t_0)/\tau}) + V_{out,initial}$$

# %% [markdown]
#
# <center><h5>On offset compensation</h5></center>
#
# The DAC used to apply the input voltage has an offset. That is, it has a constant voltage that is summed all the time to all of it's outputs, no matter (ideally) the input. We can compensate for it by starting from the consideration that the ADC used to measure the FOI output is correct.
#
# Because the FOI, as the name suggests, tries to follow the given input, we can jsut apply our desired input voltage and measure what the FOI does. The difference between these values will be the offset voltage of the DAC. By substracting this offset voltage from the desired input, we acquire the **offset compensated** value.
#
# In essence, the `foi_compensate_vin()`is:
# ```python
# def foi_compensate_vin(V):
#     p.set_foi_vin(V)           # set vin
#     time.sleep(0.5)            # wait for steady state (Vout follows Vin)
#     Vo = p.measure_foi_vout()  # measure Vout with correct ADC
#     Voff = Vo - V              # compute offset voltage
#     Vcorr = V - Voff           # compute offset compensated input
#
#     return Vcorr
# ```
# </div>

# %% [markdown]
# ### 4.2.3 Compute the time constant $\tau$ by reading from the decay in the curve

# %% [markdown]
# * Assume the input step happens at exactly $t=0$, <font color=#108ee9 markdown="1">what is the expression of $V_{out}$ at $t = \tau$</font>?

# %% [markdown]
# <div markdown="1">
# In the prelab, the transfer function of the follower-integrator was derived to be
#
# $$H(s) = \dfrac{V_{out}}{V_{in}} = \dfrac{1}{\tau s + 1}$$
#
# It is known that the unit step can be described in the s-plane as
# $$U(s) = \dfrac{\Delta V_{in}}{s}$$
#
# The unit step response can thus be evaluated to
# $$V(s) = H(s)U(s) = \dfrac{\Delta V_{in}}{s(\tau s +1)}$$
#
# Transformed back into the time domain, the output voltage can now be described by
# $$V_{out}(t) = \Delta V_{in}\left(1-e^{-\dfrac{t}{\tau}}\right) + V_{out}(t=0)$$
# </div>

# %% [markdown]
# $$V_{out}(t=\tau) = {\,???} $$

# %% [markdown]
# * Compute $\tau$ by "reading" this point from the curve:

# %%
fun = interpolate.interp1d(Vout_foi_small, t[10:]) # Interpolate t vs. Vout ie the inverse of the above plot

# %%
v_tau = Delta_Vin_foi_small * (1 - np.exp(-1)) + Vout_foi_small[0] # insert your answer from the previous question
ef(v_tau)
# Out:
# 408.83m

# %%
tau_foi = float(fun(v_tau)) # Get tau = t(Vout=1-e^(-1))
display(Markdown(f"$\\tau$ = {ef(tau_foi)}s"))
# Out:
# $\tau$ = 627.58us

# %% [markdown]
# * Compute the actual $\kappa$ by comparing the measured $\tau$ and the estimated value in 4.2.1 with $\kappa=1$.

# %%
Ibe  = 200e-12
Ibm  = Ib
taue = 250e-6
taum = tau_foi 
kappa_foi = (taue * Ibe) / (taum * Ibm)
display(Markdown(f"$\kappa$ = {kappa_foi:02.3f}"))
# Out:
# $\kappa$ = 0.398

# %%
savevars(datapath/'4.2.3_tau', overwrite=True)
# Out:
# [INFO]: 2025-11-03 11:34:45,819 - saveloadvars - Saved to data/lab6/4.2.3_tau variables [ datapath Ib Delta_Vin_foi_small Vin_start_foi trans_time_step iter_num Vout_foi_small t cutoff step fig ax v_tau tau_foi Ibe Ibm taue taum kappa_foi ] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 219, in savevars)
# [WARNING]: 2025-11-03 11:34:45,820 - saveloadvars - could not pickle: ['p'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 221, in savevars)

# %% [markdown]
# ## 4.3 Time-domain response of large signal

# %% [markdown]
# ### 4.3.1 Set parameters

# %% [markdown]
# * Having now understood how the follower-integrator behaves with a _"small signal"_ at its input, we investigate the opposite scenario, in which we feed it a _"large signal"_.

# %% [markdown]
#  <font color=#108ee9 markdown="1">
#
# * Decide on a good value of $\Delta$ for a _"large signal"_ analysis
# </font>

# %%
Delta_Vin_foi_large = 100e-3 # insert your big signal delta
ef(Delta_Vin_foi_large)
# Out:
# 100m

# %% [markdown]
# * Let's still set ADC sampling rate as 100 kHz (10 $\mu$s), and the maximum number of samples as 250. <font color=#108ee9 markdown="1">If we want the linear part to be about 40% of the whole sampled period, what should the slew rate be?</font>
#
# _Hint: the slew rate SR is measured in V/s_

# %% [markdown]
# $$T_{total} = n \times \frac{1}{100\mathrm{kHz}} = 250 \times 10\,\mu s = 2500\,\mu s = 2.5\,ms$$
# $$t_{linear} = 0.4 \times T_{total} = 0.4 \times 2.5\,ms = 1\,ms$$
#
# $$SR = \frac{dV_{out}}{dt} = \frac{\Delta V}{t_{linear}}$$
# where $\Delta V$ is the voltage change during the slew-rate limited (linear) region.
# $$SR = \frac{\Delta V_{in}}{t_{linear}} = \frac{\Delta V_{in}}{1\,ms}$$
# If $\Delta V_{in}=100$ mV, we have:
# $$SR = \frac{0.1\,V}{1\,ms} = 100\,V/s$$

# %% [markdown]
# * <font color=#108ee9 markdown="1">To get this slew rate, what is the value of $I_b$?</font>
#
# Assume $C = 1\text{pF}$.

# %% [markdown]
# From the basic capacitor equation:
# $$I = C \frac{dV}{dt}$$
# The slew rate (maximum rate of voltage change) is:
# $$SR = \frac{dV}{dt} = \frac{I_b}{C}$$
# Therefore:
# $$I_b = SR \times C$$
#
# Then, from the previous question, with $C = 1\,pF = 1 \times 10^{-12}\,F$:
# $$I_b = 100\,\frac{V}{s} \times 1 \times 10^{-12}\,F = 100 \times 10^{-12}\,A = \boxed{100\,pA}$$

# %% [markdown]
# * Set the correct `fine` given the `MasterCurrent` to achieve the $I_{b}$ current you found.
#
# _Hint: you should probably ask a TA to check if your result is correct before continuing._

# %%
Ib = p.set_foi_ib(pyplane.Coach.BiasGenMasterCurrent.I460pA, 19) # insert here your values
print(f'The Ib current is set to {ef(Ib)}A')
# Out:
# The Ib current is set to 102.82pA

# %% [markdown]
# ### 4.3.2 Data aquisition

# %%
# the DAC has an offset, same as before
Vin_start_foi = p.foi_compensate_vin(0.4)

# %%
trans_time_step = 20e-6
iter_num = 10

Vout_foi_large = np.zeros(511)

# we run experiment multiple times to average the result and remove noise
for _ in tqdm(range(iter_num)):
    _ = p.set_foi_vin(Vin_start_foi)
    time.sleep(0.5)        # wait for the cirucit to reach steady state
    # run a transient response analysis
    # we record for 20 us (511) samples and store the result
    Vout_foi_large += p.transient_response( \
        pyplane.DacChannel.AIN9,      \
        pyplane.AdcChannel.AOUT10,    \
        trans_time_step,              \
        Vin_start_foi + Delta_Vin_foi_large)
    time.sleep(0.5)         # wait to receive the measured data from the microcontroller

Vout_foi_large /= iter_num
# Out:
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]

# %%
t = np.arange(-10, len(Vout_foi_large)) * trans_time_step

# how many samples to print
# 0 < cutoff < 511
# too small and we don't see the steady state
# too big and the transition is hidden in the scale
cutoff = 150

step = np.ones(len(t)) * Vin_start_foi
step[10:] += Delta_Vin_foi_large

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(t[10:10 + cutoff], Vout_foi_large[:cutoff])
plt.plot(t[:cutoff], step[:cutoff], 'r--', linewidth=0.7, alpha=0.7)
plt.plot(t[:cutoff], np.ones(len(t[:cutoff])) * Vin_start_foi, 'k', linewidth=0.4, alpha=0.7)
plt.xlabel('$t$ [s]')
plt.ylabel('$V_{out}$ [V]')
plt.legend(
    [
        f"$V_{{out}}$",
        f"$V_{{in}} = {ef(Delta_Vin_foi_large)}V \cdot u(t) + {ef(Vin_start_foi)}V$"
    ], prop={'size': 14})
plt.title('Fig. 2: Step response of the follower-integrator for large signals')
plt.show()

# %%
# if the data looks nice, save it!
savevars(datapath/'foi_large_4.3.2', overwrite=True)
# Out:
# [INFO]: 2025-11-03 11:35:58,086 - saveloadvars - Saved to data/lab6/foi_large_4.3.2 variables [ datapath Ib Delta_Vin_foi_small Vin_start_foi trans_time_step iter_num Vout_foi_small t cutoff step fig ax v_tau tau_foi Ibe Ibm taue taum kappa_foi Delta_Vin_foi_large Vout_foi_large ] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 219, in savevars)
# [WARNING]: 2025-11-03 11:35:58,086 - saveloadvars - could not pickle: ['p'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 221, in savevars)

# %%
# maybe you need to load your saved data?
#loadvars(datapath/'foi_large_4.3.2', overwrite=True)
# Out:
# [INFO]: 2025-11-03 10:53:15,998 - saveloadvars - from data/lab6/foi_large_4.3.2 loaded variables ['datapath', 'Ib', 'Delta_Vin_foi_small', 'Vin_start_foi', 'trans_time_step', 'iter_num', 'Vout_foi_small', 't', 'cutoff', 'step', 'fig', 'ax', 'v_tau', 'tau_foi', 'Ibe', 'Ibm', 'taue', 'taum', 'kappa_foi', 'Delta_Vin_foi_large', 'Vout_foi_large'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 287, in loadvars)
# [INFO]: 2025-11-03 10:53:29,646 - saveloadvars - overwrote existing variables ['datapath', 'Ib', 'Delta_Vin_foi_small', 'Vin_start_foi', 'trans_time_step', 'iter_num', 'Vout_foi_small', 't', 'cutoff', 'step', 'fig', 'ax', 'v_tau', 'tau_foi', 'Ibe', 'Ibm', 'taue', 'taum', 'kappa_foi', 'Delta_Vin_foi_large', 'Vout_foi_large'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 325, in loadvars)

# %% [markdown]
# ### 4.3.3 Data processing

# %% [markdown]
# * We can fit two lines to the two regions of the curve.

# %%
pol_slope = np.polyfit(t[10:10+30], Vout_foi_large[:30], deg=1)
pol_plane = np.polyfit(t[:30], Vout_foi_large[-30:], deg=1)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(t[10:10 + cutoff], Vout_foi_large[:cutoff])
plt.plot(t[10:60 + 10], np.polyval(pol_slope, t[10:60 + 10]), color='r', linewidth=1)
plt.plot(t[cutoff-120:cutoff], np.polyval(pol_plane, t[:120]), color='g', linewidth=1)

plt.xlabel('$t$ [ms]')
plt.ylabel('$V_{out}$ [V]')
plt.legend([
    '$V_{out}$',
    'Slope fit',
    'Plateau fit'
    ],
    prop={'size': 12})
plt.title('Fig. 3: Step response of the follower-integrator for large signals, fitted in its two regions')
plt.show()

a = pol_slope[0]
b = pol_slope[1]
c = pol_plane[0]
d = pol_plane[1]

display(Markdown("""
The two fitted polynomial can be written as
$$\\text{Slope fit} = a \cdot t + b$$
$$\\text{Plateau fit} = c \cdot t + d$$
"""))
display(Markdown(f"Where\n\n|a|b|c|d|\n|-|-|-|-|\n|{a:.3f}|{b:.3f}|{c:.3f}|{d:.3f}|\n"))
# Out:
# The two fitted polynomial can be written as
# $$\text{Slope fit} = a \cdot t + b$$
# $$\text{Plateau fit} = c \cdot t + d$$
# Where
#
# |a|b|c|d|
# |-|-|-|-|
# |68.480|0.398|0.523|0.499|

# %% [markdown]
# *  <font color=#108ee9 markdown="1">From the four parameters a, b, c and d listed above, can you get the slew rate SR of the FOI? The value must be in **V/s**.</font>

# %% [markdown]
# We have from the fitted polynomials:
#
# - Slope fit: $a \cdot t + b$ (describes the slew-rate limited region)
# - Plateau fit: $c \cdot t + d$ (describes the steady-state region)
#
# Taking the derivative:
# $$\frac{dV_{out}}{dt} = a$$
# Therefore:
# $$\boxed{SR = a \text{ [V/s]}= 68.480}$$

# %% [markdown]
# * <font color=#108ee9 markdown="1">Calculate the bias current $I_b$ from the slew rate and compare it with the set value. Comment on possible reason of any discrepancy.</font>

# %% [markdown]
# From the basic capacitor equation:
# $$I = C \frac{dV}{dt}$$
# The slew rate (maximum rate of voltage change) is:
# $$SR = \frac{dV}{dt} = \frac{I_b}{C}$$
# Therefore:
# $$I_b = SR \times C$$
#
# Then, from the previous question, with $C = 1\,pF = 1 \times 10^{-12}\,F$:
# $$I_b = 68.480\,\frac{V}{s} \times 1 \times 10^{-12}\,F = 100 \times 10^{-12}\,A = \boxed{68.480\,pA}$$

# %% [markdown]
# This can be due to possible current mirror mismatch or subthreshold mismatch where the kappa value differs from small signal operation.

# %% [markdown]
# ## 4.4 Frequency-domain response

# %% [markdown]
# ### 4.4.1 Methodology

# %% [markdown]
# In the prelab we have computed the magnitude of the transfer function $H(s)$. In this exercise we are going to measure this curve.
#
# From the theory, we know what the general output of the follower integrator to a sine wave input will be (after several cycles). $V_{out}$ will be the same sine wave of $V_{in}$, properly phase shifted and scale in amplitude depending on the frequency of the input.

# %% [markdown]
# * In order to make the measurement more accurate, we set $I_b$ to minimum (about 70 pA):

# %%
Ib = p.set_foi_ib(pyplane.Coach.BiasGenMasterCurrent.I60pA, 100)
ef(Ib)
# Out:
# 70.59p

# %% [markdown]
# * With this $I_b$, what is the cutoff frequency approximately? <font color=#108ee9 markdown="1">Calculate it using the valus for $\kappa$ found in the previous exercises and $C = 1\text{pF}$.</font>

# %% [markdown]
# $$H(s) = \frac{1}{\tau s + 1}$$
#
# The cutoff frequency (3 dB point) occurs at:
# $$f_c = \frac{1}{2\pi\tau}$$
#
# From the follower-integrator time constant:
# $$\tau = \frac{2U_T C}{\kappa I_b}$$
#
# Therefore:
# $$f_c = \frac{\kappa I_b}{4\pi U_T C}$$
#
# Given values:
# $\kappa = 0.398$
# $I_b \approx 70\,pA$ (minimum bias current)
# $U_T = 25\,mV$
# $C = 1\,pF$
#
# Calculation:
# $$f_c = \frac{\kappa I_b}{4\pi U_T C}$$
# $$f_c = \frac{0.398 \times 70 \times 10^{-12}}{4\pi \times 25 \times 10^{-3} \times 1 \times 10^{-12}}$$
# $$f_c = \frac{27.86 \times 10^{-12}}{314.16 \times 10^{-15}} = \frac{27.86}{314.16} \times 10^{3}$$
# $$f_c \approx \boxed{88.7\,Hz}$$
#
# Alternative using time constant:
# $$\tau = \frac{2 U_T C}{\kappa I_b} = \frac{2 \times 25\,mV \times 1\,pF}{0.398 \times 70\,pA}$$
# $$\tau = \frac{50 \times 10^{-15}}{27.86 \times 10^{-12}} \approx 1.79\,\text{ms}$$
# $$f_c = \frac{1}{2\pi\tau} = \frac{1}{2\pi \times 1.79 \times 10^{-3}} \approx \boxed{88.9\,Hz}$$

# %%
#savevars(datapath/'4.4.1_fc')
# Out:
# [INFO]: 2025-11-03 11:41:25,074 - saveloadvars - Saved to data/lab6/4.4.1_fc variables [ datapath Ib Delta_Vin_foi_small Vin_start_foi trans_time_step iter_num Vout_foi_small t cutoff step fig ax v_tau tau_foi Ibe Ibm taue taum kappa_foi Delta_Vin_foi_large Vout_foi_large pol_slope pol_plane a b c d ] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 219, in savevars)
# [WARNING]: 2025-11-03 11:41:25,074 - saveloadvars - could not pickle: ['p'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 221, in savevars)

# %% [markdown]
# ### 4.4.2 Observe the input and output waveforms

# %%
loadvars(datapath/'4.4.1_fc')
# Out:
# [INFO]: 2025-11-03 12:34:26,940 - saveloadvars - from data/lab6/4.4.1_fc loaded variables ['datapath', 'Ib', 'Delta_Vin_foi_small', 'Vin_start_foi', 'trans_time_step', 'iter_num', 'Vout_foi_small', 't', 'cutoff', 'step', 'fig', 'ax', 'v_tau', 'tau_foi', 'Ibe', 'Ibm', 'taue', 'taum', 'kappa_foi', 'Delta_Vin_foi_large', 'Vout_foi_large', 'pol_slope', 'pol_plane', 'a', 'b', 'c', 'd'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 287, in loadvars)
# [INFO]: 2025-11-03 12:34:29,630 - saveloadvars - overwrote existing variables ['datapath'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 325, in loadvars)

# %% [markdown]
# * We create a sign wave that spans four periods

# %%
wave_form = np.sin(np.arange(0, 3*3.14, 0.1))
print(wave_form)

plt.plot(wave_form)
plt.show()
# Out:
# [ 0.          0.09983342  0.19866933  0.29552021  0.38941834  0.47942554
#   0.56464247  0.64421769  0.71735609  0.78332691  0.84147098  0.89120736
#   0.93203909  0.96355819  0.98544973  0.99749499  0.9995736   0.99166481
#   0.97384763  0.94630009  0.90929743  0.86320937  0.8084964   0.74570521
#   0.67546318  0.59847214  0.51550137  0.42737988  0.33498815  0.23924933
#   0.14112001  0.04158066 -0.05837414 -0.15774569 -0.2555411  -0.35078323
#  -0.44252044 -0.52983614 -0.61185789 -0.68776616 -0.7568025  -0.81827711
#  -0.87157577 -0.91616594 -0.95160207 -0.97753012 -0.993691   -0.99992326
#  -0.99616461 -0.98245261 -0.95892427 -0.92581468 -0.88345466 -0.83226744
#  -0.77276449 -0.70554033 -0.63126664 -0.55068554 -0.46460218 -0.37387666
#  -0.2794155  -0.1821625  -0.0830894   0.0168139   0.1165492   0.21511999
#   0.31154136  0.40484992  0.49411335  0.57843976  0.6569866   0.72896904
#   0.79366786  0.85043662  0.8987081   0.93799998  0.96791967  0.98816823
#   0.99854335  0.99894134  0.98935825  0.96988981  0.94073056  0.90217183
#   0.85459891  0.79848711  0.7343971   0.66296923  0.58491719  0.50102086
#   0.41211849  0.31909836  0.22288991  0.12445442  0.02477543]

# %% [markdown]
# * Set the input voltage (offset of the input sine wave is $V_{cm}=0.9$, amplitude of the input sine wave is $V_{d}=0.1$).

# %%
p.set_waveform(0.9 + 0.1 * wave_form)

# %% [markdown]
# * Plot $V_{in}$ and $V_{out}$ in the same figure

# %%
iter_num = 10

Vout_foi_sine = np.zeros(len(wave_form) + 1)

# we run experiment multiple times to average the result and remove noise
for _ in tqdm(range(iter_num)):
    time.sleep(0.5)
    Vout_foi_sine += p.measure_foi_waveform(0.01)

Vout_foi_sine /= iter_num
# Out:
# 100%|██████████| 10/10 [00:14<00:00,  1.47s/it]

# %%
t = np.arange(0, len(Vout_foi_sine)) * 0.01

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(t[:-1], 0.9 + 0.1 * wave_form)
plt.plot(t[:-5], Vout_foi_sine[:-5])
plt.title('Fig. 4: waveform response of the follower-integrator')
plt.xlabel("$t$ [s]")
plt.ylabel("$V_{out}$ [V]")
plt.legend([
    "$V_{in}$",
    "$V_{out}$"
], prop={"size": 14})
plt.show()

# %%
# if the data looks nice, save it!
#savevars(datapath/'4.4.2_input_output_waveform')
# Out:
# [INFO]: 2025-11-03 12:22:46,357 - saveloadvars - Saved to data/lab6/4.4.2_input_output_waveform variables [ datapath Ib Delta_Vin_foi_small Vin_start_foi trans_time_step iter_num Vout_foi_small t cutoff step fig ax v_tau tau_foi Ibe Ibm taue taum kappa_foi Delta_Vin_foi_large Vout_foi_large pol_slope pol_plane a b c d wave_form Vout_foi_sine ] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 219, in savevars)
# [WARNING]: 2025-11-03 12:22:46,358 - saveloadvars - could not pickle: ['p'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 221, in savevars)

# %%
# maybe you need to load your saved data?
loadvars(datapath/'4.4.2_input_output_waveform')

# %% [markdown]
# * <font color=#108ee9 markdown="1">Based on the data, is the circuit _"following"_ or _"integrating"_?</font>

# %% [markdown]
# The circuit is following since the amplitude and phase are nearly identique. Since we are below the cutoff, the circuit is in it's follower regime

# %% [markdown]
# * The code cells below are a copy of the ones above. <font color=#108ee9 markdown="1">Change the input such that the FOI operates in the other regime compared to the previous case.</font> _(ie if previously it was following, now it should be integrating and vice versa)_

# %%
# Generate a 100 Hz sine wave with max 120 points

num_points = 120
frequency =150  # Hz
duration = 0.01 #num_points * 0.01  # Duration based on sampling interval

# Create time array and sine wave
t_wave = np.linspace(0, duration, num_points)
wave_form = np.sin(2 * np.pi * frequency * t_wave)

print(wave_form)
print(t_wave)

plt.plot(t_wave, wave_form)
plt.show()
# Out:
# [ 0.00000000e+00  7.91170425e-02  1.57738074e-01  2.35370193e-01
#   3.11526698e-01  3.85730138e-01  4.57515308e-01  5.26432163e-01
#   5.92048639e-01  6.53953365e-01  7.11758240e-01  7.65100867e-01
#   8.13646821e-01  8.57091753e-01  8.95163291e-01  9.27622754e-01
#   9.54266640e-01  9.74927912e-01  9.89477037e-01  9.97822801e-01
#   9.99912882e-01  9.95734176e-01  9.85312882e-01  9.68714334e-01
#   9.46042594e-01  9.17439797e-01  8.83085266e-01  8.43194380e-01
#   7.98017227e-01  7.47837039e-01  6.92968413e-01  6.33755336e-01
#   5.70569037e-01  5.03805651e-01  4.33883739e-01  3.61241666e-01
#   2.86334849e-01  2.09632904e-01  1.31616700e-01  5.27753471e-02
#  -2.63968718e-02 -1.05403600e-01 -1.83749518e-01 -2.60943449e-01
#  -3.36501439e-01 -4.09949789e-01 -4.80828028e-01 -5.48691796e-01
#  -6.13115633e-01 -6.73695644e-01 -7.30052033e-01 -7.81831482e-01
#  -8.28709371e-01 -8.70391805e-01 -9.06617463e-01 -9.37159234e-01
#  -9.61825643e-01 -9.80462047e-01 -9.92951609e-01 -9.99216026e-01
#  -9.99216026e-01 -9.92951609e-01 -9.80462047e-01 -9.61825643e-01
#  -9.37159234e-01 -9.06617463e-01 -8.70391805e-01 -8.28709371e-01
#  -7.81831482e-01 -7.30052033e-01 -6.73695644e-01 -6.13115633e-01
#  -5.48691796e-01 -4.80828028e-01 -4.09949789e-01 -3.36501439e-01
#  -2.60943449e-01 -1.83749518e-01 -1.05403600e-01 -2.63968718e-02
#   5.27753471e-02  1.31616700e-01  2.09632904e-01  2.86334849e-01
#   3.61241666e-01  4.33883739e-01  5.03805651e-01  5.70569037e-01
#   6.33755336e-01  6.92968413e-01  7.47837039e-01  7.98017227e-01
#   8.43194380e-01  8.83085266e-01  9.17439797e-01  9.46042594e-01
#   9.68714334e-01  9.85312882e-01  9.95734176e-01  9.99912882e-01
#   9.97822801e-01  9.89477037e-01  9.74927912e-01  9.54266640e-01
#   9.27622754e-01  8.95163291e-01  8.57091753e-01  8.13646821e-01
#   7.65100867e-01  7.11758240e-01  6.53953365e-01  5.92048639e-01
#   5.26432163e-01  4.57515308e-01  3.85730138e-01  3.11526698e-01
#   2.35370193e-01  1.57738074e-01  7.91170425e-02  3.67394040e-16]
# [0.00000000e+00 8.40336134e-05 1.68067227e-04 2.52100840e-04
#  3.36134454e-04 4.20168067e-04 5.04201681e-04 5.88235294e-04
#  6.72268908e-04 7.56302521e-04 8.40336134e-04 9.24369748e-04
#  1.00840336e-03 1.09243697e-03 1.17647059e-03 1.26050420e-03
#  1.34453782e-03 1.42857143e-03 1.51260504e-03 1.59663866e-03
#  1.68067227e-03 1.76470588e-03 1.84873950e-03 1.93277311e-03
#  2.01680672e-03 2.10084034e-03 2.18487395e-03 2.26890756e-03
#  2.35294118e-03 2.43697479e-03 2.52100840e-03 2.60504202e-03
#  2.68907563e-03 2.77310924e-03 2.85714286e-03 2.94117647e-03
#  3.02521008e-03 3.10924370e-03 3.19327731e-03 3.27731092e-03
#  3.36134454e-03 3.44537815e-03 3.52941176e-03 3.61344538e-03
#  3.69747899e-03 3.78151261e-03 3.86554622e-03 3.94957983e-03
#  4.03361345e-03 4.11764706e-03 4.20168067e-03 4.28571429e-03
#  4.36974790e-03 4.45378151e-03 4.53781513e-03 4.62184874e-03
#  4.70588235e-03 4.78991597e-03 4.87394958e-03 4.95798319e-03
#  5.04201681e-03 5.12605042e-03 5.21008403e-03 5.29411765e-03
#  5.37815126e-03 5.46218487e-03 5.54621849e-03 5.63025210e-03
#  5.71428571e-03 5.79831933e-03 5.88235294e-03 5.96638655e-03
#  6.05042017e-03 6.13445378e-03 6.21848739e-03 6.30252101e-03
#  6.38655462e-03 6.47058824e-03 6.55462185e-03 6.63865546e-03
#  6.72268908e-03 6.80672269e-03 6.89075630e-03 6.97478992e-03
#  7.05882353e-03 7.14285714e-03 7.22689076e-03 7.31092437e-03
#  7.39495798e-03 7.47899160e-03 7.56302521e-03 7.64705882e-03
#  7.73109244e-03 7.81512605e-03 7.89915966e-03 7.98319328e-03
#  8.06722689e-03 8.15126050e-03 8.23529412e-03 8.31932773e-03
#  8.40336134e-03 8.48739496e-03 8.57142857e-03 8.65546218e-03
#  8.73949580e-03 8.82352941e-03 8.90756303e-03 8.99159664e-03
#  9.07563025e-03 9.15966387e-03 9.24369748e-03 9.32773109e-03
#  9.41176471e-03 9.49579832e-03 9.57983193e-03 9.66386555e-03
#  9.74789916e-03 9.83193277e-03 9.91596639e-03 1.00000000e-02]

# %%
p.set_waveform(0.9 + 0.1 * wave_form)

# %%
iter_num = 10

Vout_foi_sine = np.zeros(len(wave_form) + 1)

# we run experiment multiple times to average the result and remove noise
for _ in tqdm(range(iter_num)):
    time.sleep(0.5)
    Vout_foi_sine += p.measure_foi_waveform(0.0001)

Vout_foi_sine /= iter_num
# Out:
# 100%|██████████| 10/10 [00:05<00:00,  1.93it/s]

# %%
t = np.arange(0, len(Vout_foi_sine)) * 0.0001

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot(t[:-1], 0.9 + 0.1 * wave_form)
plt.plot(t[:-5], Vout_foi_sine[:-5])
plt.title('Fig. 5: waveform response of the follower-integrator')
plt.xlabel("$t$ [s]")
plt.ylabel("$V_{out}$ [V]")
plt.legend([
    "$V_{in}$",
    "$V_{out}$"
], prop={"size": 14})
plt.show()

# %%
savevars(datapath/'4.4.2_lab_end')
# Out:
# [INFO]: 2025-11-03 12:52:37,852 - saveloadvars - Saved to data/lab6/4.4.2_lab_end variables [ datapath Ib Delta_Vin_foi_small Vin_start_foi trans_time_step iter_num Vout_foi_small t cutoff step fig ax v_tau tau_foi Ibe Ibm taue taum kappa_foi Delta_Vin_foi_large Vout_foi_large pol_slope pol_plane a b c d wave_form Vout_foi_sine num_points frequency duration t_wave ] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 219, in savevars)
# [WARNING]: 2025-11-03 12:52:37,853 - saveloadvars - could not pickle: ['p'] (File "/Users/mariusfauteux/Documents/CoACH-labs/.conda/lib/python3.9/site-packages/jupyter_save_load_vars.py", line 221, in savevars)

# %%
p.close()
# Out:
# [INFO]: 2025-11-03 12:53:06,741 - NE1 - closing device (deleting pyplane.Plane() object (File "/Users/mariusfauteux/Documents/NE1-CoACH-LABS/ne1.py", line 250, in close)

# %% [markdown]
# ## 4.5 Optional tasks

# %% [markdown]
# * What information does a transfer function give when computing it at a specific frequency?

# %% [markdown]
# * How do you extract the cutoff freqeuncy from the analytical expression of a transfer function? Show it for the follower-integrator's TF.

# %% [markdown]
# * If you have time, try changing the `Delta_Vin_foi_*` values to negative numbers and note if anything changes.
